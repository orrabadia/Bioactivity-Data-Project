# %% [markdown]
# # **Computational Drug Discovery**
#
# Om Rabadia
#
# Using data science to build a machine learning model.
#
# Data is given using the [*ChEMBL bioactivity*](https://www.ebi.ac.uk/chembl/) database (Version 33, Data as of September 30, 2023)

# %%
! pip install chembl_webresource_client
# Using Conda environment
# Command Purpose : Pull data from the database
# Out:
# Requirement already satisfied: chembl_webresource_client in /Users/om/anaconda3/lib/python3.11/site-packages (0.10.8)
# Requirement already satisfied: urllib3 in /Users/om/anaconda3/lib/python3.11/site-packages (from chembl_webresource_client) (1.26.16)
# Requirement already satisfied: requests>=2.18.4 in /Users/om/anaconda3/lib/python3.11/site-packages (from chembl_webresource_client) (2.31.0)
# Requirement already satisfied: requests-cache~=0.7.0 in /Users/om/anaconda3/lib/python3.11/site-packages (from chembl_webresource_client) (0.7.5)
# Requirement already satisfied: easydict in /Users/om/anaconda3/lib/python3.11/site-packages (from chembl_webresource_client) (1.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/om/anaconda3/lib/python3.11/site-packages (from requests>=2.18.4->chembl_webresource_client) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/om/anaconda3/lib/python3.11/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/om/anaconda3/lib/python3.11/site-packages (from requests>=2.18.4->chembl_webresource_client) (2023.7.22)
# Requirement already satisfied: attrs<22.0,>=21.2 in /Users/om/anaconda3/lib/python3.11/site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (21.4.0)
# Requirement already satisfied: itsdangerous>=2.0.1 in /Users/om/anaconda3/lib/python3.11/site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.0.1)
# Requirement already satisfied: pyyaml>=5.4 in /Users/om/anaconda3/lib/python3.11/site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0)
# Requirement already satisfied: url-normalize<2.0,>=1.4 in /Users/om/anaconda3/lib/python3.11/site-packages (from requests-cache~=0.7.0->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: six in /Users/om/anaconda3/lib/python3.11/site-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.16.0)

# %%
import pandas as pd #library for working with datasets
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# We will be searching for Target proteins that cause Alzheimers

# %%
target_search = new_client.target.search('Alzheimers')
targets = pd.DataFrame.from_dict(target_search)
targets
# Out:
#                                     cross_references           organism  \
# 0                                                 []       Homo sapiens
# 1  [{'xref_id': 'Q92542', 'xref_name': None, 'xre...       Homo sapiens
# 2                                                 []       Homo sapiens
# 3                                                 []  Rattus norvegicus
# 4                                                 []       Mus musculus
# 5  [{'xref_id': 'P05067', 'xref_name': None, 'xre...       Homo sapiens
#
#                                    pref_name  score  species_group_flag  \
# 0  Nucleosome-remodeling factor subunit BPTF    6.0               False
# 1                                  Nicastrin    5.0               False
# 2                            Gamma-secretase    5.0               False
# 3                    Amyloid beta A4 protein    4.0               False
# 4                    Amyloid-beta A4 protein    4.0               False
# 5                    Beta amyloid A4 protein    3.0               False
#
#   target_chembl_id                                  target_components  \
# 0    CHEMBL3085621  [{'accession': 'Q12830', 'component_descriptio...
# 1       CHEMBL3418  [{'accession': 'Q92542', 'component_descriptio...
# 2    CHEMBL2094135  [{'accession': 'Q96BI3', 'component_descriptio...
# 3    CHEMBL3638365  [{'accession': 'P08592', 'component_descriptio...
# 4    CHEMBL4523942  [{'accession': 'P12023', 'component_descriptio...
# 5       CHEMBL2487  [{'accession': 'P05067', 'component_descriptio...
#
#        target_type  tax_id
# 0   SINGLE PROTEIN    9606
# 1   SINGLE PROTEIN    9606
# 2  PROTEIN COMPLEX    9606
# 3   SINGLE PROTEIN   10116
# 4   SINGLE PROTEIN   10090
# 5   SINGLE PROTEIN    9606

# %% [markdown]
# We will be selecting Entry 5 (Beta amyloid A4 protein), as this protein contributes to Alzheimer pathogenesis.

# %%
BetaA4Amyloid = targets.target_chembl_id[5]
BetaA4Amyloid
# Out:
# 'CHEMBL2487'

# %% [markdown]
# Now we want to filter and retrieve data for the Beta amyloid A4 protein, which is identified as CHEMBL2487, that is reported as IC50 values (measure of drug efficacy).
#
# IC50 is reported in nM.

# %%
resulting_list = new_client.activity.filter(target_chembl_id=BetaA4Amyloid)
resulting_listIC50filter = resulting_list.filter(standard_type="IC50")
dataframe = pd.DataFrame.from_dict(resulting_listIC50filter)
dataframe.head(4) #show first 4
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None       357577                  []
# 1        None             None       357580                  []
# 2        None             None       358965                  []
# 3        None             None       368887                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL678443  Inhibition of A-beta-42 production by inhibiti...
# 1    CHEMBL678443  Inhibition of A-beta-42 production by inhibiti...
# 2    CHEMBL678443  Inhibition of A-beta-42 production by inhibiti...
# 3    CHEMBL678443  Inhibition of A-beta-42 production by inhibiti...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
# 3          B                    None                   None  BAO_0000190  ...
#
#   target_organism         target_pref_name target_tax_id text_value  toid  \
# 0    Homo sapiens  Beta amyloid A4 protein          9606       None  None
# 1    Homo sapiens  Beta amyloid A4 protein          9606       None  None
# 2    Homo sapiens  Beta amyloid A4 protein          9606       None  None
# 3    Homo sapiens  Beta amyloid A4 protein          9606       None  None
#
#    type units    uo_units upper_value value
# 0  IC50    uM  UO_0000065        None   5.0
# 1  IC50    uM  UO_0000065        None   2.7
# 2  IC50    uM  UO_0000065        None   1.8
# 3  IC50    uM  UO_0000065        None  11.0
#
# [4 rows x 46 columns]
